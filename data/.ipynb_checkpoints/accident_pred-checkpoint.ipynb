# %%
pip install plotly
# Out:
# Collecting plotly
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/a5/07/5bef9376c975ce23306d9217ab69ca94c07f2a3c90b17c03e3ae4db87170/plotly-5.15.0-py2.py3-none-any.whl.metadata
#   Downloading plotly-5.15.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from plotly) (23.1)
# Downloading plotly-5.15.0-py2.py3-none-any.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 22.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.15.0 tenacity-8.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('/Users/jaeyeon/Desktop/위험지수예측모델/data/세종시사고.csv')
df.head() #5행의 데이터 확인
# Out:
#                사고번호             사고일시   요일           시군구  사고내용  사망자수  중상자수  \
# 0  2022010200100246  2022년 1월 2일 17시  일요일  세종특별자치시 조치원읍  중상사고     0     1
# 1  2022010300100081  2022년 1월 3일 07시  월요일   세종특별자치시 어진동  경상사고     0     0
# 2  2022010300100318  2022년 1월 3일 14시  월요일   세종특별자치시 아름동  경상사고     0     0
# 3  2022010500100442  2022년 1월 5일 21시  수요일   세종특별자치시 한솔동  경상사고     0     0
# 4  2022010500100459  2022년 1월 5일 22시  수요일  세종특별자치시 조치원읍  경상사고     0     0
#
#    경상자수  부상신고자수        사고유형  ... 기상상태        도로형태 가해운전자 차종 가해운전자 성별 가해운전자 연령  \
# 0     0       0  차대사람 - 횡단중  ...   맑음  교차로 - 교차로안       승용        여      74세
# 1     1       0    차대차 - 기타  ...   맑음    단일로 - 기타       승용        남      69세
# 2     1       0   차대사람 - 기타  ...   맑음     기타 - 기타       승합        남      43세
# 3     1       0    차대차 - 기타  ...   맑음    단일로 - 기타       승용        남      49세
# 4     1       0   차대사람 - 기타  ...   맑음    단일로 - 기타       승용        남      23세
#
#   가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도
# 0       상해없음      보행자        남      58세         중상
# 1       상해없음       승용        여      26세         경상
# 2       상해없음      보행자        여      55세         경상
# 3       상해없음       승합        남      59세       상해없음
# 4       상해없음      보행자        여      81세         경상
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932 entries, 0 to 931
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사고번호        932 non-null    int64
#  1   사고일시        932 non-null    object
#  2   요일          932 non-null    object
#  3   시군구         932 non-null    object
#  4   사고내용        932 non-null    object
#  5   사망자수        932 non-null    int64
#  6   중상자수        932 non-null    int64
#  7   경상자수        932 non-null    int64
#  8   부상신고자수      932 non-null    int64
#  9   사고유형        932 non-null    object
#  10  법규위반        932 non-null    object
#  11  노면상태        932 non-null    object
#  12  기상상태        932 non-null    object
#  13  도로형태        932 non-null    object
#  14  가해운전자 차종    932 non-null    object
#  15  가해운전자 성별    932 non-null    object
#  16  가해운전자 연령    932 non-null    object
#  17  가해운전자 상해정도  932 non-null    object
#  18  피해운전자 차종    891 non-null    object
#  19  피해운전자 성별    891 non-null    object
#  20  피해운전자 연령    891 non-null    object
#  21  피해운전자 상해정도  891 non-null    object
# dtypes: int64(5), object(17)
# memory usage: 160.3+ KB

# %%
sum = []
for i in range(len(df)):
    sum.append(df['사망자수'][i] + df['중상자수'][i]+df['경상자수'][i]+df['부상신고자수'][i])
df['사상자합계'] = sum

# %%
df.head()
# Out:
#                사고번호             사고일시   요일           시군구  사고내용  사망자수  중상자수  \
# 0  2022010200100246  2022년 1월 2일 17시  일요일  세종특별자치시 조치원읍  중상사고     0     1
# 1  2022010300100081  2022년 1월 3일 07시  월요일   세종특별자치시 어진동  경상사고     0     0
# 2  2022010300100318  2022년 1월 3일 14시  월요일   세종특별자치시 아름동  경상사고     0     0
# 3  2022010500100442  2022년 1월 5일 21시  수요일   세종특별자치시 한솔동  경상사고     0     0
# 4  2022010500100459  2022년 1월 5일 22시  수요일  세종특별자치시 조치원읍  경상사고     0     0
#
#    경상자수  부상신고자수        사고유형  ...        도로형태 가해운전자 차종 가해운전자 성별 가해운전자 연령  \
# 0     0       0  차대사람 - 횡단중  ...  교차로 - 교차로안       승용        여      74세
# 1     1       0    차대차 - 기타  ...    단일로 - 기타       승용        남      69세
# 2     1       0   차대사람 - 기타  ...     기타 - 기타       승합        남      43세
# 3     1       0    차대차 - 기타  ...    단일로 - 기타       승용        남      49세
# 4     1       0   차대사람 - 기타  ...    단일로 - 기타       승용        남      23세
#
#   가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도 사상자합계
# 0       상해없음      보행자        남      58세         중상     1
# 1       상해없음       승용        여      26세         경상     1
# 2       상해없음      보행자        여      55세         경상     1
# 3       상해없음       승합        남      59세       상해없음     1
# 4       상해없음      보행자        여      81세         경상     1
#
# [5 rows x 23 columns]

# %%
df.to_csv("accident.csv",index = False, encoding="utf-8-sig")

# %%
X = df[['노면상태','기상상태','요일','도로형태','사상자합계']]

# %%
print(type(X))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df['시군구'].value_counts()
# Out:
# 시군구
# 세종특별자치시 조치원읍    130
# 세종특별자치시 나성동      81
# 세종특별자치시 어진동      67
# 세종특별자치시 아름동      54
# 세종특별자치시 고운동      46
# 세종특별자치시 도담동      46
# 세종특별자치시 소담동      42
# 세종특별자치시 다정동      42
# 세종특별자치시 종촌동      40
# 세종특별자치시 대평동      37
# 세종특별자치시 금남면      37
# 세종특별자치시 새롬동      36
# 세종특별자치시 장군면      35
# 세종특별자치시 연기면      30
# 세종특별자치시 전의면      23
# 세종특별자치시 보람동      22
# 세종특별자치시 부강면      21
# 세종특별자치시 연서면      19
# 세종특별자치시 반곡동      19
# 세종특별자치시 한솔동      18
# 세종특별자치시 전동면      14
# 세종특별자치시 세종동      13
# 세종특별자치시 소정면      11
# 세종특별자치시 연동면      11
# 세종특별자치시 집현동      10
# 세종특별자치시 해밀동       8
# 세종특별자치시 산울동       6
# 세종특별자치시 가람동       6
# 세종특별자치시 합강동       4
# 세종특별자치시 한별동       2
# 세종특별자치시 다솜동       1
# 세종특별자치시 용호동       1
# Name: count, dtype: int64

# %%
y =df['시군구']

# %%
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/33/cb/0e41fad5b30fd66925e47952ddc720d078bdfd8397584a4873ec1cf590ca/scikit_learn-1.3.0-cp38-cp38-macosx_10_9_x86_64.whl.metadata
#   Downloading scikit_learn-1.3.0-cp38-cp38-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from scikit-learn) (1.24.4)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Using cached scipy-1.10.1-cp38-cp38-macosx_10_9_x86_64.whl (35.0 MB)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading scikit_learn-1.3.0-cp38-cp38-macosx_10_9_x86_64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 12.7 MB/s eta 0:00:00m eta 0:00:01:01:01
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 29.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.0 scipy-1.10.1 threadpoolctl-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['노면상태'].unique()
# Out:
# array(['건조', '젖음/습기', '서리/결빙', '기타', '해빙', '적설'], dtype=object)

# %%
df['노면상태'].unique().tolist()
# Out:
# ['건조', '젖음/습기', '서리/결빙', '기타', '해빙', '적설']

# %%
df['노면상태'].unique().tolist().index('건조')
# Out:
# 0

# %%
temp_list =df['노면상태'].unique().tolist()
df['노면상태'].map(lambda x : temp_list.index(x))
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 927    0
# 928    0
# 929    0
# 930    0
# 931    0
# Name: 노면상태, Length: 932, dtype: int64

# %%
df.insert(12, '노면상태_label', df['노면상태'].map(lambda x : temp_list.index(x)))

# %%
df.tail()
# Out:
#                  사고번호               사고일시   요일           시군구  사고내용  사망자수  중상자수  \
# 927  2022123000100016  2022년 12월 30일 00시  금요일  세종특별자치시 조치원읍  중상사고     0     1
# 928  2022123000100017  2022년 12월 30일 00시  금요일   세종특별자치시 금남면  경상사고     0     0
# 929  2022123000100415  2022년 12월 30일 16시  금요일   세종특별자치시 아름동  경상사고     0     0
# 930  2022123000100675  2022년 12월 30일 22시  금요일   세종특별자치시 소담동  경상사고     0     0
# 931  2022123100100137  2022년 12월 31일 09시  토요일   세종특별자치시 해밀동  경상사고     0     0
#
#      경상자수  부상신고자수        사고유형  ...         도로형태     가해운전자 차종  가해운전자 성별  \
# 927     2       0    차대차 - 기타  ...  교차로 - 교차로부근           승용         남
# 928     2       0    차대차 - 추돌  ...     단일로 - 기타           승용         남
# 929     1       1  차대사람 - 횡단중  ...  교차로 - 교차로부근  개인형이동수단(PM)         남
# 930     2       0  차대차 - 측면충돌  ...   교차로 - 교차로안           이륜         남
# 931     2       0  차대차 - 측면충돌  ...   교차로 - 교차로안           이륜         남
#
#     가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도 사상자합계
# 927      58세       상해없음       승용        남      56세         경상     3
# 928      58세       상해없음       승용        남      56세         경상     2
# 929      17세       부상신고      보행자        남      15세         경상     2
# 930      30세         경상       승용        여      51세         경상     2
# 931      24세         경상       승용        남      33세         경상     2
#
# [5 rows x 24 columns]

# %%
df1 = df.loc[:,['사고일시','요일','시군구','노면상태','노면상태_label','기상상태','도로형태','사상자합계']]

# %%
df1.tail()
# Out:
#                   사고일시   요일           시군구 노면상태  노면상태_label 기상상태         도로형태  \
# 927  2022년 12월 30일 00시  금요일  세종특별자치시 조치원읍   건조           0   맑음  교차로 - 교차로부근
# 928  2022년 12월 30일 00시  금요일   세종특별자치시 금남면   건조           0   기타     단일로 - 기타
# 929  2022년 12월 30일 16시  금요일   세종특별자치시 아름동   건조           0   흐림  교차로 - 교차로부근
# 930  2022년 12월 30일 22시  금요일   세종특별자치시 소담동   건조           0   맑음   교차로 - 교차로안
# 931  2022년 12월 31일 09시  토요일   세종특별자치시 해밀동   건조           0   맑음   교차로 - 교차로안
#
#      사상자합계
# 927      3
# 928      2
# 929      2
# 930      2
# 931      2

# %%
df1['기상상태'].unique()
# Out:
# array(['맑음', '흐림', '눈', '기타', '비', '안개'], dtype=object)

# %%
temp_list2 =df1['기상상태'].unique().tolist()

# %%
df1.insert(6, '기상상태_label', df1['기상상태'].map(lambda x : temp_list2.index(x)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kf/j0gdz6014055ff32gdvy_kvw0000gn/T/ipykernel_11532/3552285583.py in ?()
# ----> 1 df1.insert(6, '기상상태_label', df1['기상상태'].map(lambda x : temp_list2.index(x)))
#
# /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    4768                 "'self.flags.allows_duplicate_labels' is False."
#    4769             )
#    4770         if not allow_duplicates and column in self.columns:
#    4771             # Should this be a different kind of error??
# -> 4772             raise ValueError(f"cannot insert {column}, already exists")
#    4773         if not isinstance(loc, int):
#    4774             raise TypeError("loc must be int")
#    4775
#
# ValueError: cannot insert 기상상태_label, already exists

# %%
df1
# Out:
#                   사고일시   요일           시군구 노면상태  노면상태_label 기상상태         도로형태  \
# 0      2022년 1월 2일 17시  일요일  세종특별자치시 조치원읍   건조           0   맑음   교차로 - 교차로안
# 1      2022년 1월 3일 07시  월요일   세종특별자치시 어진동   건조           0   맑음     단일로 - 기타
# 2      2022년 1월 3일 14시  월요일   세종특별자치시 아름동   건조           0   맑음      기타 - 기타
# 3      2022년 1월 5일 21시  수요일   세종특별자치시 한솔동   건조           0   맑음     단일로 - 기타
# 4      2022년 1월 5일 22시  수요일  세종특별자치시 조치원읍   건조           0   맑음     단일로 - 기타
# ..                 ...  ...           ...  ...         ...  ...          ...
# 927  2022년 12월 30일 00시  금요일  세종특별자치시 조치원읍   건조           0   맑음  교차로 - 교차로부근
# 928  2022년 12월 30일 00시  금요일   세종특별자치시 금남면   건조           0   기타     단일로 - 기타
# 929  2022년 12월 30일 16시  금요일   세종특별자치시 아름동   건조           0   흐림  교차로 - 교차로부근
# 930  2022년 12월 30일 22시  금요일   세종특별자치시 소담동   건조           0   맑음   교차로 - 교차로안
# 931  2022년 12월 31일 09시  토요일   세종특별자치시 해밀동   건조           0   맑음   교차로 - 교차로안
#
#      기상상태_label  사상자합계
# 0             0      1
# 1             0      1
# 2             0      1
# 3             0      1
# 4             0      1
# ..          ...    ...
# 927           0      3
# 928           3      2
# 929           1      2
# 930           0      2
# 931           0      2
#
# [932 rows x 9 columns]

# %%
df1['도로형태'].unique()
# Out:
# array(['교차로 - 교차로안', '단일로 - 기타', '기타 - 기타', '단일로 - 고가도로위', '교차로 - 교차로부근',
#        '주차장 - 주차장', '단일로 - 터널', '교차로 - 교차로횡단보도내', '단일로 - 지하차도(도로)내',
#        '단일로 - 교량'], dtype=object)

# %%
df1['요일'].unique()
# Out:
# array(['일요일', '월요일', '수요일', '목요일', '금요일', '화요일', '토요일'], dtype=object)

# %%
temp_list3 =df1['도로형태'].unique().tolist()
df1.insert(8, '도로형태_label', df1['도로형태'].map(lambda x : temp_list3.index(x)))

# %%
temp_list4 =df1['요일'].unique().tolist()
df1.insert(3, '요일_label', df1['요일'].map(lambda x : temp_list4.index(x)))

# %%
df1
# Out:
#                   사고일시   요일           시군구  요일_label 노면상태  노면상태_label 기상상태  \
# 0      2022년 1월 2일 17시  일요일  세종특별자치시 조치원읍         0   건조           0   맑음
# 1      2022년 1월 3일 07시  월요일   세종특별자치시 어진동         1   건조           0   맑음
# 2      2022년 1월 3일 14시  월요일   세종특별자치시 아름동         1   건조           0   맑음
# 3      2022년 1월 5일 21시  수요일   세종특별자치시 한솔동         2   건조           0   맑음
# 4      2022년 1월 5일 22시  수요일  세종특별자치시 조치원읍         2   건조           0   맑음
# ..                 ...  ...           ...       ...  ...         ...  ...
# 927  2022년 12월 30일 00시  금요일  세종특별자치시 조치원읍         4   건조           0   맑음
# 928  2022년 12월 30일 00시  금요일   세종특별자치시 금남면         4   건조           0   기타
# 929  2022년 12월 30일 16시  금요일   세종특별자치시 아름동         4   건조           0   흐림
# 930  2022년 12월 30일 22시  금요일   세종특별자치시 소담동         4   건조           0   맑음
# 931  2022년 12월 31일 09시  토요일   세종특별자치시 해밀동         6   건조           0   맑음
#
#             도로형태  기상상태_label  도로형태_label  사상자합계
# 0     교차로 - 교차로안           0           0      1
# 1       단일로 - 기타           0           1      1
# 2        기타 - 기타           0           2      1
# 3       단일로 - 기타           0           1      1
# 4       단일로 - 기타           0           1      1
# ..           ...         ...         ...    ...
# 927  교차로 - 교차로부근           0           4      3
# 928     단일로 - 기타           3           1      2
# 929  교차로 - 교차로부근           1           4      2
# 930   교차로 - 교차로안           0           0      2
# 931   교차로 - 교차로안           0           0      2
#
# [932 rows x 11 columns]

# %%
df1.to_csv("accident_labeling.csv",index = False, encoding="utf-8-sig")

# %%
temp_list5 =df1['시군구'].unique().tolist()

# %%
temp_list5
# Out:
# ['세종특별자치시 조치원읍',
#  '세종특별자치시 어진동',
#  '세종특별자치시 아름동',
#  '세종특별자치시 한솔동',
#  '세종특별자치시 새롬동',
#  '세종특별자치시 소담동',
#  '세종특별자치시 고운동',
#  '세종특별자치시 연동면',
#  '세종특별자치시 다정동',
#  '세종특별자치시 집현동',
#  '세종특별자치시 나성동',
#  '세종특별자치시 연기면',
#  '세종특별자치시 종촌동',
#  '세종특별자치시 소정면',
#  '세종특별자치시 장군면',
#  '세종특별자치시 전동면',
#  '세종특별자치시 부강면',
#  '세종특별자치시 보람동',
#  '세종특별자치시 세종동',
#  '세종특별자치시 도담동',
#  '세종특별자치시 금남면',
#  '세종특별자치시 연서면',
#  '세종특별자치시 산울동',
#  '세종특별자치시 대평동',
#  '세종특별자치시 전의면',
#  '세종특별자치시 반곡동',
#  '세종특별자치시 해밀동',
#  '세종특별자치시 합강동',
#  '세종특별자치시 가람동',
#  '세종특별자치시 다솜동',
#  '세종특별자치시 용호동',
#  '세종특별자치시 한별동']

# %%
temp_list5 =df1['시군구'].unique().tolist()
df1.insert(1, '시군구_label', df1['시군구'].map(lambda x : temp_list5.index(x)))

# %%
df1
# Out:
#                   사고일시  시군구_label   요일           시군구  요일_label 노면상태  \
# 0      2022년 1월 2일 17시          0  일요일  세종특별자치시 조치원읍         0   건조
# 1      2022년 1월 3일 07시          1  월요일   세종특별자치시 어진동         1   건조
# 2      2022년 1월 3일 14시          2  월요일   세종특별자치시 아름동         1   건조
# 3      2022년 1월 5일 21시          3  수요일   세종특별자치시 한솔동         2   건조
# 4      2022년 1월 5일 22시          0  수요일  세종특별자치시 조치원읍         2   건조
# ..                 ...        ...  ...           ...       ...  ...
# 927  2022년 12월 30일 00시          0  금요일  세종특별자치시 조치원읍         4   건조
# 928  2022년 12월 30일 00시         20  금요일   세종특별자치시 금남면         4   건조
# 929  2022년 12월 30일 16시          2  금요일   세종특별자치시 아름동         4   건조
# 930  2022년 12월 30일 22시          5  금요일   세종특별자치시 소담동         4   건조
# 931  2022년 12월 31일 09시         26  토요일   세종특별자치시 해밀동         6   건조
#
#      노면상태_label 기상상태         도로형태  기상상태_label  도로형태_label  사상자합계
# 0             0   맑음   교차로 - 교차로안           0           0      1
# 1             0   맑음     단일로 - 기타           0           1      1
# 2             0   맑음      기타 - 기타           0           2      1
# 3             0   맑음     단일로 - 기타           0           1      1
# 4             0   맑음     단일로 - 기타           0           1      1
# ..          ...  ...          ...         ...         ...    ...
# 927           0   맑음  교차로 - 교차로부근           0           4      3
# 928           0   기타     단일로 - 기타           3           1      2
# 929           0   흐림  교차로 - 교차로부근           1           4      2
# 930           0   맑음   교차로 - 교차로안           0           0      2
# 931           0   맑음   교차로 - 교차로안           0           0      2
#
# [932 rows x 12 columns]

# %%
X = df1[['노면상태_label','기상상태_label','요일_label','도로형태_label','사상자합계']]

# %%
y =df1['시군구_label']

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=10)
print('훈련 데이터: ', X_train.shape)
print('검증 데이터:', X_test.shape)
# Out:
# 훈련 데이터:  (745, 5)
# 검증 데이터: (187, 5)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
r_square = lr.score(X_test, y_test)
r_square
# Out:
# -0.00593169327211629

# %%
print("회귀식의 기울기 (a)", lr.coef_)
# Out:
# 회귀식의 기울기 (a) [ 1.0089378  -0.59612269  0.14030355 -0.12128872  0.66162854]

# %%
print("회귀식의 y절편 (b)", lr.intercept_)
# Out:
# 회귀식의 y절편 (b) 9.170573962440669

# %%
y_hat = lr.predict(X_test)

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 2.2 MB/s eta 0:00:002.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=0.25 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (6.0.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.16.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/jupyter/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
ax1 = sns.kdeplot(y_test, label="y_test") 
ax2 = sns.kdeplot(y_hat, label='y_hat', ax=ax1)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[95], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#       4 plt.figure(figsize=(10,5))
#       5 ax1 = sns.kdeplot(y_test, label="y_test")
#
# ModuleNotFoundError: No module named 'seaborn'
